# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
import seaborn as sns 

df = pd.read_csv('data/labelled/labelled_data.csv')

print(df)
# Out:
#                    Image_Path     Label
# 0    data/cuted/page_1001.png  DESPACHO
# 1    data/cuted/page_1003.png       NaN
# 2    data/cuted/page_1005.png  DESPACHO
# 3    data/cuted/page_1006.png  DESPACHO
# 4    data/cuted/page_1007.png       NaN
# ..                        ...       ...
# 181   data/cuted/page_992.png  DESPACHO
# 182   data/cuted/page_993.png  DESPACHO
# 183   data/cuted/page_996.png  DESPACHO
# 184   data/cuted/page_997.png  DESPACHO
# 185   data/cuted/page_999.png  DESPACHO
#
# [186 rows x 2 columns]

# %%
data = df['Label'].value_counts().reset_index()

labels = data['count']
tamanhos = data['Label']
plt.barh(tamanhos, labels,align='center')
# Out:
# <BarContainer object of 11 artists>
