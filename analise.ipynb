# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
import seaborn as sns 

df = pd.read_csv('data/labelled/labelled_data.csv')

print(df)
# Out:
#                            Image_Path       Label
# 0            data/cuted/page_1001.png    DESPACHO
# 1            data/cuted/page_1003.png         NaN
# 2            data/cuted/page_1005.png    DESPACHO
# 3            data/cuted/page_1006.png    DESPACHO
# 4            data/cuted/page_1007.png         NaN
# ..                                ...         ...
# 351  data/cuted/process1/page_987.png    DESPACHO
# 352  data/cuted/process1/page_988.png    DESPACHO
# 353  data/cuted/process1/page_990.png  REQUISICAO
# 354  data/cuted/process1/page_992.png  REQUISICAO
# 355  data/cuted/process1/page_999.png    DESPACHO
#
# [356 rows x 2 columns]

# %%
data = df['Label'].value_counts().reset_index()

labels = data['count']
tamanhos = data['Label']
plt.barh(tamanhos, labels,align='center')
# Out:
# <BarContainer object of 16 artists>
