# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
import seaborn as sns 

df = pd.read_csv('data/labelled/labelled_data.csv')

print(df)
# Out:
#                            Image_Path       Label
# 0            data/cuted/page_1001.png    DESPACHO
# 1            data/cuted/page_1003.png         NaN
# 2            data/cuted/page_1005.png    DESPACHO
# 3            data/cuted/page_1006.png    DESPACHO
# 4            data/cuted/page_1007.png         NaN
# ..                                ...         ...
# 266  data/cuted/process1/page_987.png    DESPACHO
# 267  data/cuted/process1/page_988.png    DESPACHO
# 268  data/cuted/process1/page_990.png  REQUISICAO
# 269  data/cuted/process1/page_992.png  REQUISICAO
# 270  data/cuted/process1/page_999.png    DESPACHO
#
# [271 rows x 2 columns]

# %%
data = df['Label'].value_counts().reset_index()

labels = data['Label']
tamanhos = data['count']
plt.barh(labels, tamanhos,align='center')
# Out:
# <BarContainer object of 15 artists>

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from tensorflow.keras.preprocessing import image
#       4 from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
#       5 from sklearn.decomposition import PCA
#
# ModuleNotFoundError: No module named 'tensorflow'
