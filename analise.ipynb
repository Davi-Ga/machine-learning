# %%
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd
import seaborn as sns 

df = pd.read_csv('data/labelled/labelled_data_final.csv')

df = df.dropna(subset=['Label'])

print(df)
# Out:
#                             Image_Path        Label
# 1    data/cuted/process1/page_1001.png     DESPACHO
# 3    data/cuted/process1/page_1005.png     DESPACHO
# 4    data/cuted/process1/page_1006.png     DESPACHO
# 8    data/cuted/process1/page_1090.png     Consulta
# 9    data/cuted/process1/page_1091.png     DESPACHO
# ..                                 ...          ...
# 813    data/cuted/process5/page_89.png     CERTIDAO
# 814    data/cuted/process5/page_90.png  NOTIFICACAO
# 815    data/cuted/process5/page_91.png     CERTIDAO
# 816    data/cuted/process5/page_92.png     CERTIDAO
# 817    data/cuted/process5/page_94.png     DESPACHO
#
# [713 rows x 2 columns]

# %%
data = df['Label'].value_counts().reset_index()

labels = data['Label']
tamanhos = data['count']
plt.barh(labels, tamanhos,align='center')
# Out:
# <BarContainer object of 16 artists>
